# %%
# Google Drive를 Mount하기
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Vision Transformer구현과 관련된 파일들이 존재하는 Directory로 이동한다
# !cd/content/gdrive/My Drive/VisionTransformer

# 그리고 현재 Directory의 파일 출력
# !ls -al .
# Out:
# /bin/bash: cd/content/gdrive/My: No such file or directory
# total 3826
# -rw------- 1 root root    6148 Oct  5  2021 .DS_Store
# -rw------- 1 root root 3325281 Aug 16 13:16 model.pth
# -rw------- 1 root root    7260 Aug 29 06:25 model.py
# -rw------- 1 root root    5245 Aug 28 13:49 patchdata.py
# -rw------- 1 root root     792 Sep 23  2021 test.py
# -rw------- 1 root root  561352 Mar  3 06:01 visualization.ipynb
# -rw------- 1 root root    2751 Aug 29 07:43 vit.ipynb
# -rw------- 1 root root    6036 Aug 28 14:12 vit.py

# %%
# --pretrained : pretrained model의 weight를 사용 (model.pth라는 사전 훈련된 weights)
# --drop_rate : dropout계층의 rate를 0.1로 설정
# --weight_decay : L2 Regularization 2e-4로 설정
# !python vit.py --pretrained 1 --drop_rate 0.1 --weight_decay 2e-4

# %%
# test mode로 시행하기
# !python vit.py --pretrained 1 --mode test
# Out:
# Namespace(batch_size=128, dataname='cifar10', drop_rate=0.1, epochs=501, img_size=32, latent_vec_dim=128, lr=0.002, mode='test', num_classes=10, num_heads=8, num_layers=12, patch_size=4, pretrained=1, save_acc=50, weight_decay=0)
# ...
# 170499072it [00:03, 47095510.84it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# test loss: 0.501, test acc 84.64 %
